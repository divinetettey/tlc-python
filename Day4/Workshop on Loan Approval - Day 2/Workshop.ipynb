# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
from IPython.display import display
# %matplotlib inline

# %%
# Display the number of columns

loan_df = pd.read_csv('train.csv')
display(loan_df)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
# columns 

loan_df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
loan_df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
loan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
loan_df.groupby('Loan_Status').ApplicantIncome.sum().plot(kind='bar')

# %%
loan_df.groupby('Loan_Status').CoapplicantIncome.sum().plot(kind='bar')

# %%
# delete rows with missing loan amount and loan term 

# indexToDrop = loan_df[ (loan_df['Loan_Status'] == "Y")  & (loan_df['LoanAmount'].isna() ) ].index

# loan_df.dropna(inplace=True, axis=0)

# loan_df.drop(indexToDrop, inplace=True)
# loan_df

# %%
# change the value of loan status to 1 or 0
# loan_df.loc[loan_df['Loan_Status'] == 'Y','Loan_Status']=  1
# loan_df.loc[loan_df['Loan_Status'] == 'N','Loan_Status']=  0

# # fill nan with mean
# loan_df = loan_df.fillna(loan_df.mean())

outcomes = loan_df['Loan_Status']

features_raw = loan_df.drop('Loan_Status', axis=1)
display(features_raw.head())
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0  146.412162             360.0
# 1             4583             1508.0  128.000000             360.0
# 2             3000                0.0   66.000000             360.0
# 3             2583             2358.0  120.000000             360.0
# 4             6000                0.0  141.000000             360.0
#
#    Credit_History Property_Area
# 0             1.0         Urban
# 1             1.0         Rural
# 2             1.0         Urban
# ...

# %%
# features_no_id = features_raw.drop(['Loan_ID'],axis=1)
# features_no_id

# one-hot-encoding
# features = pd.get_dummies(features_no_id)
# features
# #fill in the blanks
#features =  features.fillna(0.0)
display(features.head())
# Out:
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0  146.412162             360.0
# 1               4583             1508.0  128.000000             360.0
# 2               3000                0.0   66.000000             360.0
# 3               2583             2358.0  120.000000             360.0
# 4               6000                0.0  141.000000             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0   71.000000             360.0
# 610             4106                0.0   40.000000             180.0
# 611             8072              240.0  253.000000             360.0
# 612             7583                0.0  187.000000             360.0
# 613             4583                0.0  133.000000             360.0
#
#      Credit_History  Gender_Female  Gender_Male  Married_No  Married_Yes  \
# ...

# %%
# wrangling of test data 

# test_df = pd.read_csv('test.csv')

# test_no_id = test_df.drop(['Loan_ID'],axis=1)

test_features = test_no_id.fillna(test_no_id.mean())
display(test_features)
# Out:
# C:\Users\divine.tettey\AppData\Local\Temp\ipykernel_14964\698379178.py:7: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   test_features = test_no_id.fillna(test_no_id.mean())
#     Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0     Male     Yes          0      Graduate            No             5720
# 1     Male     Yes          1      Graduate            No             3076
# 2     Male     Yes          2      Graduate            No             5000
# 3     Male     Yes          2      Graduate            No             2340
# 4     Male      No          0  Not Graduate            No             3276
# ..     ...     ...        ...           ...           ...              ...
# ...

# %%
# train the data 
from sklearn.model_selection import train_test_split
X_train, x_test, Y_train, y_test = train_test_split(features, outcomes, test_size=0.2, random_state=42)
# Out:
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 83              6000             2250.0  265.000000             360.0
# 90              2958             2900.0  131.000000             360.0
# 227             6250             1695.0  210.000000             360.0
# 482             2083             3150.0  128.000000             360.0
# 464             4166                0.0   98.000000             360.0
# ..               ...                ...         ...               ...
# 71              1875             1875.0   97.000000             360.0
# 106            11417             1126.0  225.000000             360.0
# 270             3237                0.0   30.000000             360.0
# 435            10047                0.0  146.412162             240.0
# 102            13650                0.0  146.412162             360.0
#
#      Credit_History  Gender_Female  Gender_Male  Married_No  Married_Yes  \
# ...

# %%
# import the classifier and fit the data 
from sklearn.tree import DecisionTreeClassifier

decision = DecisionTreeClassifier() 
decision.fit(X_train, Y_train)

loan_pred = decision.predict(X_train)
test_pred = decision.predict(x_test)

from sklearn.metrics import accuracy_score
train_accurracy = accuracy_score(Y_train,loan_pred)
print('The training accurracy is: ', train_accurracy)

# test_data = pd.read_csv('test.csv')
test_accuracy = accuracy_score(y_test, test_pred)
print('The test accurracy: ', test_accuracy)
# Out:
# The training accurracy is:  1.0
# The test accurracy:  0.6829268292682927

# %%
# Tweak The model 

decision = DecisionTreeClassifier(max_depth=4,min_samples_leaf=14, min_samples_split=10) 
decision.fit(X_train, Y_train)


loan_pred = decision.predict(X_train)
test_pred = decision.predict(x_test)

train_accurracy = accuracy_score(Y_train,loan_pred)
print('The training accurracy is: ', train_accurracy)

# test_data = pd.read_csv('test.csv')
test_accuracy = accuracy_score(y_test, test_pred)
print('The test accurracy: ', test_accuracy)
# Out:
# The training accurracy is:  0.814663951120163
# The test accurracy:  0.7804878048780488

# %%
from sklearn.ensemble import RandomForestClassifier

forest = RandomForestClassifier(criterion='entropy')
forest.fit(X_train, Y_train)

loan_pred = forest.predict(X_train)
test_pred = forest.predict(x_test)

train_accurracy = accuracy_score(Y_train,loan_pred)
print('The training accurracy is: ', train_accurracy)

# test_data = pd.read_csv('test.csv')
test_accuracy = accuracy_score(y_test, test_pred)
print('The test accurracy: ', test_accuracy)
# Out:
# The training accurracy is:  1.0
# The test accurracy:  0.7804878048780488

# %%
from sklearn.linear_model import LogisticRegression

logistic = LogisticRegression(max_iter=10000)
logistic.fit(X_train, Y_train)

loan_pred = logistic.predict(X_train)
test_pred = logistic.predict(x_test)

train_accurracy = accuracy_score(Y_train,loan_pred)
print('The training accurracy is: ', train_accurracy)

# test_data = pd.read_csv('test.csv')
test_accuracy = accuracy_score(y_test, test_pred)
print('The test accurracy: ', test_accuracy)
# Out:
# The training accurracy is:  0.8187372708757638
# The test accurracy:  0.7642276422764228

# %%
from sklearn.ensemble import GradientBoostingClassifier

boost = GradientBoostingClassifier()
boost.fit(X_train, Y_train)

loan_pred = boost.predict(X_train)
test_pred = boost.predict(x_test)

train_accurracy = accuracy_score(Y_train,loan_pred)
print('The training accurracy is: ', train_accurracy)

# test_data = pd.read_csv('test.csv')
test_accuracy = accuracy_score(y_test, test_pred)
print('The test accurracy: ', test_accuracy)
# Out:
# The training accurracy is:  0.9022403258655805
# The test accurracy:  0.7642276422764228

# %%
# Support Vector Machines 
from sklearn.svm  import SVR

svm = SVR()

svm.fit(X_train, Y_train)

loan_pred = svm.predict(X_train)
test_pred = svm.predict(x_test)

train_accurracy = accuracy_score(Y_train,loan_pred)
# print('The training accurracy is: ', train_accurracy)

# # test_data = pd.read_csv('test.csv')
# test_accuracy = accuracy_score(y_test, test_pred)
# print('The test accurracy: ', test_accuracy)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[74], line 11
#       8 loan_pred = svm.predict(X_train)
#       9 test_pred = svm.predict(x_test)
# ---> 11 train_accurracy = accuracy_score(Y_train,loan_pred)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\sklearn\utils\_param_validation.py:192, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     187 validate_parameter_constraints(
#     188     parameter_constraints, params, caller_name=func.__qualname__
#     189 )
#     191 try:
# --> 192     return func(*args, **kwargs)
#     193 except InvalidParameterError as e:
#     194     # When the function is just a wrapper around an estimator, we allow
#     195     # the function to delegate validation to the estimator, but we replace
#     196     # the name of the estimator by the name of the function in the error
# ...
